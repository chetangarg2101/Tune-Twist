# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 3.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 8.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 61.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 7.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 38.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.9 MB/s eta 0:00:00

# %%
import os
import torch
from datasets import load_dataset
from datasets import Dataset
from peft import LoraConfig, PeftModel
from trl import SFTTrainer
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)

# %%
import pandas as pd

csv_file_path = 'lyrics-dataset.csv'
df = pd.read_csv(csv_file_path)

result_list = []

for index, row in df.iterrows():
    article = f"English: {row['text']}"
    generated_song = f"Hinglish: {row['song']}"

    result_list.append([article, generated_song])

print(result_list[5])
# Out:
# ['English: Pimpri-Chinchwad police have busted a racket of illegally refilling domestic liquefied petroleum gas (LPG) into commercial cylinders at a godown in Chikhali area on Tuesday evening.', 'Hinglish: (Verse 1)\nPimpri-Chinchwad police ne kiya kaam bada,\nRacket bust kiya, illegal game ka parda.\nChikhali area mein, ek godown ka scene,\nTuesday evening mein, hui raid ka dream.\n\n(Chorus)\nIllegally refilling, LPG ka chakkar,\nDomestic cylinders mein, commercial ka shor.\nPolice ne kiya, action ka jor,\nChikhali mein, hua racket ka ant.\n\n(Verse 2)\nGodown mein chhupa, yeh kala dhanda,\nLPG ki tankiyo se, bhara hai andaaz.\nPolice ne pakda, criminals ka group,\nIllegal refilling, tha yeh unka scoop.\n\n(Chorus)\nIllegally refilling, LPG ka chakkar,\nDomestic cylinders mein, commercial ka shor.\nPolice ne kiya, action ka jor,\nChikhali mein, hua racket ka ant.\n\n(Bridge)\nRaat ko chhupa, clandestine operation,\nCommercial cylinders, bhara illegal sensation.\nPimpri-Chinchwad mein, hawa tight,\nPolice ne kiya, unka fight.\n\n(Chorus)\nIllegally refilling, LPG ka chakkar,\nDomestic cylinders mein, commercial ka shor.\nPolice ne kiya, action ka jor,\nChikhali mein, hua racket ka ant.']

# %%
system_prompt = "Generate a bollywood song in hindi from this"

def generate():
  for i in range(len(result_list)-2):
    yield {"text": f"[INST]<>{system_prompt}<>{result_list[i][0].strip('English: ')}[/INST]{result_list[i][1].strip('Hinglish: ')}"}

dataset = Dataset.from_generator(generate)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
model_name = "meta-llama/Llama-2-7b-hf"
new_model = "llama-2-7b-article-bollywood-song"

lora_r = 64
lora_alpha = 16
lora_dropout = 0.1

use_4bit = True
bnb_4bit_compute_dtype = "float16"
bnb_4bit_quant_type = "nf4"
use_nested_quant = False

per_device_eval_batch_size = 4
gradient_checkpointing = True

max_seq_length = None
packing = False
device_map = {"": 0}

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Token:
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map,
    use_auth_token="<Your token>"
)
model.config.use_cache = False
model.config.pretraining_tp = 1
# Out:
# config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/188 [00:00<?, ?B/s]

# %%
# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True, use_auth_token="<Your token>")
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/776 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %%
# Set training parameters
training_arguments = TrainingArguments(
    output_dir="./results",
    num_train_epochs=15,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=10000,
    logging_steps=10,
    learning_rate=5*2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
    report_to="tensorboard"
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()

# Save trained model
trainer.model.save_pretrained(new_model)
# Out:
# Map:   0%|          | 0/47 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='180' max='180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [180/180 22:16, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.390800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.035100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.832600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.638500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.545300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.387900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.273900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.167900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.134300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.085400</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.063500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.052600</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.045300</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.036900</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.030300</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.029900</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.024600</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.018900</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=500)
result = pipe(f"[INST]<>{system_prompt}<>The Indian military’s modernisation budget for 2024-25 saw a meagre hike of 6.17 per cent despite the ongoing standoff with China along the Line of Actual Control in eastern Ladakh and a slew of terror attacks on security forces in Jammu and Kashmir last year....[/INST]")

# %%
result
# Out:
# [{'generated_text': '[INST]<>Generate a bollywood song in hindi from this<>The Indian military’s modernisation budget for 2024-25 saw a meagre hike of 6.17 per cent despite the ongoing standoff with China along the Line of Actual Control in eastern Ladakh and a slew of terror attacks on security forces in Jammu and Kashmir last year....[/INST]\n(Verse 1)\nBudget mein modernisation ka, ek naya scene ka hai,\n2024-25 mein, hikayat hai 6.17 percent ka.\nIndian military ka, ek aur ek kahani,\nLadakh ke liniyon se, hai yeh ek naya scene.\n\n(Chorus)\nMeagre hike ka, ek naya dum,\nMilitary modernisation ka, hai yeh ek num.\nJammu aur Kashmir, last year ka visuals,\nSecurity forces ki, thi yeh ek crashes.\n\n(Verse 2)\nLine of Actual Control, hai yeh ek face,\nLadakh mein standoff, hai yeh ek place.\nModernisation ka, hai yeh ek plan,\nPar meagre hike ka, hai yeh ek span.\n\n(Chorus)\nMeagre hike ka, ek naya dum,\nMilitary modernisation ka, hai yeh ek num.\nJammu aur Kashmir, last year ka visuals,\nSecurity forces ki, thi yeh ek crashes.\n\n(Bridge)\nHike ka meagre, hai yeh ek face,\nMilitary modernisation ka, hai yeh ek place.\nStandoff mein, hai yeh ek sight,\nPar budget mein kaam ka, hai yeh ek night.\n\n(Chorus)\nMeagre hike ka, ek naya dum,\nMilitary modernisation ka, hai yeh ek num.\nJammu aur Kashmir, last year ka visuals,\nSecurity forces ki, thi yeh ek crashes.\n\n(Verse'}]
